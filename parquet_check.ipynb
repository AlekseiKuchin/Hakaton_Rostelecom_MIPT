# %%
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

# %%
#pq.ParquetFile('test.parquet')
test = pq.ParquetFile('export_parquet')

# %%
test.metadata
# Out:
# ...
#   created_by: parquet-cpp-arrow version 19.0.1
#   num_columns: 10
#   num_rows: 30000
#   num_row_groups: 600
#   format_version: 2.6
#   serialized_size: 645677

# %%
test.schema
# Out:
# ...
# required group field_id=-1 schema {
#   optional binary field_id=-1 ip (String);
#   optional int32 field_id=-1 timestamp (Date);
#   optional binary field_id=-1 method (String);
#   optional binary field_id=-1 path (String);
#   optional binary field_id=-1 protocol (String);
#   optional int32 field_id=-1 status;
#   optional int32 field_id=-1 bytes_sent;
#   optional binary field_id=-1 referrer (String);
#   optional binary field_id=-1 user_agent (String);
#   optional int32 field_id=-1 response_time;
# }

# %%
first_ten_rows = next(test.iter_batches(batch_size = 10)) 
df = pa.Table.from_batches([first_ten_rows]).to_pandas()
df
# Out:
#                 ip   timestamp  method                  path  protocol  \
# 0     15.74.45.114  2023-01-05  DELETE            /usr/admin  HTTP/1.0
# 1  122.239.116.246  2023-01-05     GET            /usr/login  HTTP/1.0
# 2    139.31.190.36  2023-01-05     GET  /usr/admin/developer  HTTP/1.0
# 3  196.241.201.130  2023-01-05     PUT  /usr/admin/developer  HTTP/1.0
# 4   24.165.196.101  2023-01-05     PUT            /usr/admin  HTTP/1.0
# 5     114.87.92.66  2023-01-05     PUT  /usr/admin/developer  HTTP/1.0
# 6    190.53.230.43  2023-01-05     PUT         /usr/register  HTTP/1.0
# 7    192.56.34.224  2023-01-05     GET            /usr/admin  HTTP/1.0
# 8  175.112.158.124  2023-01-05    POST                  /usr  HTTP/1.0
# 9   216.99.151.252  2023-01-05     PUT            /usr/admin  HTTP/1.0
#
#    status  bytes_sent                                          referrer  \
# 0     304        5016                                                 -
# ...
